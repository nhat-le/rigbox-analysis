# %%
from src import log_parser
from datetime import date

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.io
import smartload.smartload as smart
import datetime
import pickle

# %reload_ext autoreload
# %autoreload 2

# %%
tbl = log_parser.get_googledb_opto()

tbl.animal = [elem[:3].upper() for elem in np.array(tbl.animal)]

# Narrow down the opto sessions with f26, f27 and f29

subtbl = tbl[np.isin(tbl.animal, ['F26', 'F27', 'F29'])]
# subtbl.opto_location.unique()

subtbl.opto_location = [elem.split(' ')[0].lower() for elem in subtbl.opto_location]

#subtbl.loc[~np.isin(subtbl.opto_location, ['frontal', 'motor', 'visual', 'rsc']), 'opto_location'] = 'nan'

optotbl = subtbl.loc[np.isin(subtbl.opto_location, ['frontal', 'motor', 'visual', 'rsc']), 
                     ['date', 'animal', 'opto_location', 'opto_power', 'opto_voltage', 'ntrials', 'notes']]
# Out:
# /Users/minhnhatle/opt/anaconda3/envs/default/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# Save this table to an excel file
optotbl[optotbl.animal == 'F29']
# Out:
#          date animal opto_location opto_power opto_voltage ntrials  \
# 77   10/15/21    F29       frontal       5.75          3.7     184
# 80   10/26/21    F29       frontal        6.8          3.7     393
# 82   10/27/21    F29         motor        6.1         3.66     263
# 84   10/28/21    F29        visual        6.1         3.64     265
# 89   10/29/21    F29           rsc        6.5         3.65     312
# 98   11/01/21    F29       frontal         13         4.49     248
# 103  11/03/21    F29         motor       13.1         4.53     277
# 108  11/05/21    F29        visual       12.5         4.59     300
# 116  11/07/21    F29           rsc       13.1         4.25     277
# 121  11/09/21    F29       frontal        6.5         3.44     294
# 129  11/12/21    F29         motor        6.6         3.33     208
# 137  11/14/21    F29        visual        6.7          3.3     236
# 142  11/16/21    F29        visual        6.5         3.45     227
# ...

# %%
datestr = date.today().strftime('%Y-%m-%d')
fileloc = f'/Users/minhnhatle/Documents/ExternalCode/rigbox_analysis/opto/sessionlog_{datestr}.csv'
optotbl.to_csv(fileloc)

# %%
[datetime.datetime.strptime(elem, '%m/%d/%y').strftime('%m-%d-%Y') for elem in optotbl.date]
# Out:
# ['10-15-2021',
#  '10-26-2021',
#  '10-26-2021',
#  '10-26-2021',
#  '10-27-2021',
#  '10-27-2021',
#  '10-27-2021',
#  '10-28-2021',
#  '10-28-2021',
#  '10-28-2021',
#  '10-29-2021',
#  '10-29-2021',
#  '10-29-2021',
#  '11-01-2021',
#  '11-01-2021',
#  '11-01-2021',
#  '11-03-2021',
#  '11-03-2021',
#  '11-03-2021',
#  '11-05-2021',
#  '11-05-2021',
#  '11-05-2021',
#  '11-07-2021',
#  '11-07-2021',
#  '11-07-2021',
#  '11-09-2021',
#  '11-09-2021',
#  '11-09-2021',
#  '11-12-2021',
#  '11-12-2021',
#  '11-12-2021',
#  '11-14-2021',
#  '11-14-2021',
#  '11-14-2021',
#  '11-16-2021',
#  '11-16-2021',
#  '11-16-2021',
#  '11-18-2021',
#  '11-18-2021',
#  '11-18-2021',
#  '11-20-2021',
#  '11-20-2021',
#  '11-20-2021']
